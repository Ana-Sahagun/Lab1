# %%
#Iniciamosimportando libreria pandas
import pandas as pd

# %%
# 1. Para que te lea los 3 files de csv:
pd1=pd.read_csv(r"C:\Users\anasa\Downloads\file1.csv")
pd2=pd.read_csv(r"C:\Users\anasa\Downloads\file2.csv")
pd3=pd.read_csv(r"C:\Users\anasa\Downloads\file3.csv")

# %%
# 2. Para definir la forma de las 3 matrices de info:
pd1.shape
# Out:
# (4008, 11)

# %%
pd2.shape
# Out:
# (996, 11)

# %%
pd3.shape
# Out:
# (7070, 11)

# %%
# 3. Antes de poder estandarizar la tabla debemos ver como es cada una de ellas
# Nos fijaremos en que columnas tiene, orden, y forma (mayusculas/minuscukas)...:
pd1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
pd2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
pd3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
# 3. Lo primero es que State lo homogeneicemos, y cambiemos a ST
pd3_1=pd3.rename(columns={"State":"ST"})

# %%
pd3_1
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# 4. Para convertir todas las columas a mayusculas, vamos a sacar una lista de los titulos de cada columna 
# Luego iteraremos para convertir los otitulos a mayusculas.
columnas1=list(pd1.columns)

# %%
columnas1
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
# 4. Aqui convertimos, todos aquellos títulos que estén en minúsculas a mayúsculas:
titulos_nuevos1={}
for columna in columnas1:
    if columna.lower():
        titulos_nuevos1[columna]=columna.upper()

# %%
# 4. Para ver que efectivamente se han cambiado a mayus.
titulos_nuevos1
# Out:
# {'Customer': 'CUSTOMER',
#  'ST': 'ST',
#  'GENDER': 'GENDER',
#  'Education': 'EDUCATION',
#  'Customer Lifetime Value': 'CUSTOMER LIFETIME VALUE',
#  'Income': 'INCOME',
#  'Monthly Premium Auto': 'MONTHLY PREMIUM AUTO',
#  'Number of Open Complaints': 'NUMBER OF OPEN COMPLAINTS',
#  'Policy Type': 'POLICY TYPE',
#  'Vehicle Class': 'VEHICLE CLASS',
#  'Total Claim Amount': 'TOTAL CLAIM AMOUNT'}

# %%
# 4. Para renombrar los títlos de las columnas:
pd1=pd1.rename(columns=titulos_nuevos1)

# %%
# 4. Check de columnas:
pd1
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
columnas2=list(pd2.columns)

# %%
columnas2
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Total Claim Amount',
#  'Policy Type',
#  'Vehicle Class']

# %%
titulos_nuevos2={}
for columna in columnas2:
    if columna.lower():
        titulos_nuevos2[columna]=columna.upper()

# %%
titulos_nuevos2
# Out:
# {'Customer': 'CUSTOMER',
#  'ST': 'ST',
#  'GENDER': 'GENDER',
#  'Education': 'EDUCATION',
#  'Customer Lifetime Value': 'CUSTOMER LIFETIME VALUE',
#  'Income': 'INCOME',
#  'Monthly Premium Auto': 'MONTHLY PREMIUM AUTO',
#  'Number of Open Complaints': 'NUMBER OF OPEN COMPLAINTS',
#  'Total Claim Amount': 'TOTAL CLAIM AMOUNT',
#  'Policy Type': 'POLICY TYPE',
#  'Vehicle Class': 'VEHICLE CLASS'}

# %%
pd2=pd2.rename(columns=titulos_nuevos2)

# %%
pd2
# Out:
#     CUSTOMER          ST GENDER EDUCATION CUSTOMER LIFETIME VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  TOTAL CLAIM AMOUNT  \
# ...

# %%
columnas3_1=list(pd3_1.columns)

# %%
columnas3_1
# Out:
# ['Customer',
#  'ST',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
titulos_nuevos3_1={}
for columna in columnas3_1:
    if columna.lower():
        titulos_nuevos3_1[columna]=columna.upper()

# %%
titulos_nuevos3_1
# Out:
# {'Customer': 'CUSTOMER',
#  'ST': 'ST',
#  'Customer Lifetime Value': 'CUSTOMER LIFETIME VALUE',
#  'Education': 'EDUCATION',
#  'Gender': 'GENDER',
#  'Income': 'INCOME',
#  'Monthly Premium Auto': 'MONTHLY PREMIUM AUTO',
#  'Number of Open Complaints': 'NUMBER OF OPEN COMPLAINTS',
#  'Policy Type': 'POLICY TYPE',
#  'Total Claim Amount': 'TOTAL CLAIM AMOUNT',
#  'Vehicle Class': 'VEHICLE CLASS'}

# %%
pd3_1=pd3_1.rename(columns=titulos_nuevos3_1)

# %%
pd3_1
# Out:
#      CUSTOMER          ST  CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# ...

# %%
# 4. Para ordenarte alfabeticamente los titulos de las columnas
pd1=pd1[sorted(list(pd1.columns))]

# %%
pd2=pd2[sorted(list(pd2.columns))]

# %%
pd3_1=pd3_1[sorted(list(pd3_1.columns))]

# %%
pd3_1
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE             EDUCATION GENDER  INCOME  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
# ...

# %%
# 5. Vamos a concatenar las 3 tablas:
#las tablas importados tienen 4008+996+7070=120474 filas, pero me salen 21 columnas 
concat = pd.concat([pd1, pd2, pd3_1], axis=0)

# %%
# 5. Al concatenar vemos como el nº de columnas no cambia (11) y el de filas es la suma: 40004+996+7070=12074 : 
concat
# Out:
#      CUSTOMER CUSTOMER LIFETIME VALUE             EDUCATION GENDER   INCOME  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 7065  LA72316             23405.98798              Bachelor      M  71941.0
# 7066  PK87824             3096.511217               College      F  21604.0
# 7067  TD14365             8163.890428              Bachelor      M      0.0
# 7068  UP19263             7524.442436               College      M  21941.0
# 7069  Y167826             2611.836866               College      M      0.0
#
# ...

# %%
# 6. Numerical variables:
numerical_vars=["CUSTOMER LIFETIME VALUE", "INCOME", "MONTHLY PREMIUM AUTO", "NUMBER OF OPEN COMPLAINTS", "TOTAL CLAIM AMOUNT"]

# %%
# 7. Numerical variables:
categorical_vars=["CUSTOMER", "EDUCATION", "GENDER", "POLICY TYPE", "ST", "VEHICLE CLASS"]

# %%
# 8. ¿qué hacer respecto a "understand the meaning of all columns"?

# %%
# 9.DATA CLEANING:

# %%
# 9.1. Método drop es indicando el índice de la columna en lugar de su nombre.en este caso educacion y nº de complaints (3,7)
# Recuerda ponerte doble [[]] --> para que tenga en cuenta que aplica a una lista y para definir la lista 3,7
concat = concat.drop(["EDUCATION", "NUMBER OF OPEN COMPLAINTS"], axis="columns")

# %%
concat
# Out:
#      CUSTOMER CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 0     RB50392                     NaN    NaN      0.0                1000.0
# 1     QZ44356              697953.59%      F      0.0                  94.0
# 2     AI49188             1288743.17%      F  48767.0                 108.0
# 3     WW63253              764586.18%      M      0.0                 106.0
# 4     GA49547              536307.65%      M  36357.0                  68.0
# ...       ...                     ...    ...      ...                   ...
# 7065  LA72316             23405.98798      M  71941.0                  73.0
# 7066  PK87824             3096.511217      F  21604.0                  79.0
# 7067  TD14365             8163.890428      M      0.0                  85.0
# 7068  UP19263             7524.442436      M  21941.0                  96.0
# 7069  Y167826             2611.836866      M      0.0                  77.0
#
# ...

# %%
# 9.2 ¿? como hacer un % un nmero: --> se multiplicarlo pero no quitar el % 
# str.rstrip('%') para quitar los signos de porcentaje al final de cada cadena en las columnas especificadas.
# astype('float') para convertir las cadenas a valores flotantes.
columna_porcentu=["CUSTOMER LIFETIME VALUE"]
for i in columna_porcentu:
    concat["CUSTOMER LIFETIME VALUE"]=concat["CUSTOMER LIFETIME VALUE"].str.rstrip("%").astype("float")/100

# %%
concat
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 0     RB50392                      NaN    NaN      0.0                1000.0
# 1     QZ44356                6979.5359      F      0.0                  94.0
# 2     AI49188               12887.4317      F  48767.0                 108.0
# 3     WW63253                7645.8618      M      0.0                 106.0
# 4     GA49547                5363.0765      M  36357.0                  68.0
# ...       ...                      ...    ...      ...                   ...
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7067  TD14365                      NaN      M      0.0                  85.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
# 7069  Y167826                      NaN      M      0.0                  77.0
#
# ...

# %%
# 9.3 ¿?Para quitar duplicados como nos pide el ejercicio convertimos en data frame en un set(que ahora se llama concat):
#df_sin_duplicados = df.drop_duplicates()
concat=concat.drop_duplicates()

# %%
concat
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 0     RB50392                      NaN    NaN      0.0                1000.0
# 1     QZ44356                6979.5359      F      0.0                  94.0
# 2     AI49188               12887.4317      F  48767.0                 108.0
# 3     WW63253                7645.8618      M      0.0                 106.0
# 4     GA49547                5363.0765      M  36357.0                  68.0
# ...       ...                      ...    ...      ...                   ...
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7067  TD14365                      NaN      M      0.0                  85.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
# 7069  Y167826                      NaN      M      0.0                  77.0
#
# ...

# %%
# ¿? no se como convertir a data set para eliminar duplicados...(el paso anterior sirve pero como seria de esta forma?)

# %%
# 9.4 Tenemos que quitar a través de filtros filas con income >= a 0. Es decir quedarme con los que tienen income>0 :
# 9.4 OJO! para que te filtre no puedes poner solo concat1=concat["INCOME"]>0 porque entonces te daria una lista de los que si
# por ello has de decirle que te de la tabla concat y ademas que de la tabla contar te coja solo los de income>0

concat1=concat[concat["INCOME"]>0]

# %%
concat1
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 2     AI49188               12887.4317      F  48767.0                 108.0
# 4     GA49547                5363.0765      M  36357.0                  68.0
# 5     OC83172                8256.2978      F  62902.0                  69.0
# 6     XZ87318                5380.8986      F  55350.0                  67.0
# 8     DY87989               24127.5040      M  14072.0                  71.0
# ...       ...                      ...    ...      ...                   ...
# 7063  TF56202                      NaN      M  66367.0                  64.0
# 7064  YM19146                      NaN      F  47761.0                 104.0
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
#
# ...
